# %% [markdown]
# #**Week #4 Homework**

# %% [markdown]
# ## **Project: Visualizing Earnings by College Majors**
#
# ---
#
# ##### **Project Description**
#
# In this project, we will be looking at `recent-grads` which supplies data on graduates, their majors, and their earnings. For this week, we will hone our exploratory data analysis and data visualization tools. In the coming weeks, we will learn machine learning techniques that will help us understand and use this kind of data even more deeply!
#
# <br>
#
# ##### **Key Research Questions**
#
# This project will answer the following questions:
# * Is there any correlation between the percentage of men/women in a given major and unemployment?
# * Is there any correlation between the percentage of men/women in a given major and the number of full time jobs?
# * Is there any correlation between the percentage of men/women in a given major and median salary?
#
#
# <br>
#
# ##### **Python Cheat Sheets:**
#
# [Python Basics Cheat Sheet](https://docs.google.com/document/d/1c5LMGUa9wyxHGW49GbeOU5xLIVYyBQaLBFruwQHLFYc)
#
# [EDA and Pandas Cheat Sheet](https://docs.google.com/document/d/1AtWgIgiKwVY5QAENob-r_R3pqPIdpalFoSYDpTvZVLA)
#
# [Data Visualization in Matplotlib Cheat Sheet](https://docs.google.com/document/d/1TDM-BcXtsPKdj9WjuK6wDx485aRqo56ymhMypd9onz4)

# %% [markdown]
# ## **Getting our DataFrame in Order**

# %% [markdown]
# We will provide step-by-step instructions for this project.

# %% [markdown]
# #####**Step 0:**
#
# Import your packages! Always run this before doing anything else.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #####**Step 1:**
#
# Given the url, create the data frame we will be working in.
#
# `url = "https://docs.google.com/spreadsheets/d/e/2PACX-1vQpmKvdNBYzQUmM5JGnm3IwlsdZMKhur2uSfbBO2k9hvkIg0mbJOeXkY6xW2IZchEpCmWDzvFUaWwqJ/pub?gid=0&single=true&output=csv"`

# %%
url = "https://docs.google.com/spreadsheets/d/e/2PACX-1vQpmKvdNBYzQUmM5JGnm3IwlsdZMKhur2uSfbBO2k9hvkIg0mbJOeXkY6xW2IZchEpCmWDzvFUaWwqJ/pub?gid=0&single=true&output=csv"
earn_df = pd.read_csv(url)
earn_df.head()
# Out:
#    Rank  Major_code                                      Major  Total  Women  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339    282
# 1     2        2416             MINING AND MINERAL ENGINEERING    756     77
# 2     3        2415                  METALLURGICAL ENGINEERING    856    131
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258    135
# 4     5        2405                       CHEMICAL ENGINEERING  32260  11021
#
#      Men Major_category  ShareWomen  ShareMen  Sample_size  ...  Full_time  \
# 0   2057    Engineering    0.120564  0.879436           36  ...       1849
# 1    679    Engineering    0.101852  0.898148            7  ...        556
# 2    725    Engineering    0.153037  0.846963            3  ...        558
# 3   1123    Engineering    0.107313  0.892687           16  ...       1069
# 4  21239    Engineering    0.341631  0.658369          289  ...      23170
#
# ...

# %% [markdown]
# #####**Step 2:**
#
# Look at the different columns provided. Start thinking about which would be good columns to visualize and which may not. Write your thoughts the cell below.

# %% [markdown]
# Visualizing the total men vs. women for each major would be useful, as well as visualizing how many of these people work full time vs. part time

# %% [markdown]
# #####**Step 3:**
#
# How many unique values are there for `Major_category`?

# %%
print( earn_df['Major_category'].describe() )
print()
print("There are 16 unique values for 'Major_category'")
# Out:
# count             172
# unique             16
# top       Engineering
# freq               29
# Name: Major_category, dtype: object
#
# There are 16 unique values for 'Major_category'

# %% [markdown]
# #####**Step 4:**
#
# Look at the 156th row. What is the major category?

# %%
#156th row including 0, or not including 0?
earn_df.iloc[156:157]
# Out:
#      Rank  Major_code       Major  Total  Women   Men  \
# 156   158        3402  HUMANITIES   6652   4639  2013
#
#                 Major_category  ShareWomen  ShareMen  Sample_size  ...  \
# 156  Humanities & Liberal Arts    0.697384  0.302616           49  ...
#
#      Full_time  Part_time  Full_time_year_round  Full_time_year_percent  \
# 156       3565       2225                  2661                     NaN
#
#      Unemployed  Unemployment_rate  Median  College_jobs  Non_college_jobs  \
# 156         372           0.068584   30000          1168              3354
#
#      Low_wage_jobs
# 156           1141
#
# [1 rows x 21 columns]

# %%
print("The major category is HUMANITIES")
# Out:
# The major category is HUMANITIES

# %% [markdown]
# #####**Step 5:**
#
# Look at the 89th row. What is the `Total` number of people in this major?

# %%
earn_df.iloc[89:90]
# Out:
#     Rank  Major_code        Major  Total  Women  Men     Major_category  \
# 89    91        5005  GEOSCIENCES   1978   1169  809  Physical Sciences
#
#     ShareWomen  ShareMen  Sample_size  ...  Full_time  Part_time  \
# 89    0.591001  0.408999           18  ...       1264        354
#
#     Full_time_year_round  Full_time_year_percent  Unemployed  \
# 89                  1011                     NaN          36
#
#     Unemployment_rate  Median  College_jobs  Non_college_jobs  Low_wage_jobs
# 89           0.024374   36000           784               591            221
#
# [1 rows x 21 columns]

# %%
print("The total number of people in the GEOSCIENCES major is 1978")
# Out:
# The total number of people in the GEOSCIENCES major is 1978

# %% [markdown]
# #####**Step 6:**
#
# What is the datatype of the `Full_time` column?

# %%
earn_df['Full_time'].dtypes
# Out:
# dtype('int64')

# %% [markdown]
# #####**Step 7:**
#
# Calculate the mean, median, and sum of the `Full_time` column in the three cells below:

# %%
# Mean
earn_df['Full_time'].mean()
# Out:
# 26165.767441860466

# %%
# Median
earn_df['Full_time'].median()
# Out:
# 10073.5

# %%
# Sum
earn_df['Full_time'].sum()
# Out:
# 4500512

# %% [markdown]
# #####**Step 8:**
#
# What is the mean, median, and total number of women in this dataset?

# %%
# Mean
earn_df['Women'].mean()
# Out:
# 22646.674418604653

# %%
# Median
earn_df['Women'].median()
# Out:
# 8386.5

# %%
# Sum
earn_df['Women'].sum()
# Out:
# 3895228

# %% [markdown]
# #####**Step 9:**
#
# What is the average (mean) `ShareWomen` across majors?
#
# What is the percentage of women out of the total number of people in this dataset?

# %%
# Average ShareWomen in data
earn_df['ShareWomen'].mean()
# Out:
# 0.5222233649593023

# %%
# Percent women in data
#all women I assume, not shareWomen
totalWomen = earn_df['Women'].sum()
totalPeople = earn_df['Total'].sum()
percentage = (totalWomen / totalPeople) * 100

print("The percentage of women out of the total number of people in the dataset is %" + str(percentage))
# Out:
# The percentage of women out of the total number of people in the dataset is %57.52254914382809

# %% [markdown]
# #####**Step 10:**
#
# Write code to determine if there are more women or men on *average* (mean not median) in the majors in this dataset.
#
# **Hint**: We can use comparison operators (>, <, ==,...) here!

# %%
avgMen = earn_df['Men'].mean()
avgWomen = earn_df['Women'].mean()

if avgMen > avgWomen:
  print("There are more men than women on average across the majors in the dataset")
elif avgWomen > avgMen:
  print("There are more women than men on average across the majors in the dataset")
else:
  print("There is an equal amount of women and men on average across the majors in the dataset")
# Out:
# There are more women than men on average across the majors in the dataset

# %% [markdown]
# ## Visualizing Our Data

# %% [markdown]
# #####**Step 11:**
#
# Graph the columns `ShareMen` versus `Unemployment_rate`. Make the points navy colored and the text bold.

# %%
#I had to sort the values for each dataset, otherwise, the line of the graoh would be all over the place...
plt.scatter(earn_df['ShareMen'].sort_values(), earn_df['Unemployment_rate'].sort_values(), color='navy')
plt.title("ShareMen vs. Unemplyment Rate", fontweight='bold')
plt.xlabel("ShareMen", fontweight='bold')
plt.ylabel("Unemployment Rate", fontweight='bold')
plt.show()

# %% [markdown]
# #####**Step 12:**
#
# Let's do the same thing as step 11 but with `ShareWomen`. Make these points green.

# %%
#I had to sort the values for each dataset, otherwise, the line of the graoh would be all over the place...
plt.scatter(earn_df['ShareWomen'].sort_values(), earn_df['Unemployment_rate'].sort_values(), color='green')
plt.title("ShareWomen vs. Unemplyment Rate", fontweight='bold')
plt.xlabel("ShareWomen", fontweight='bold')
plt.ylabel("Unemployment Rate", fontweight='bold')
plt.show()

# %% [markdown]
# #####**Step 13:**
#
# The graphs from steps 11 and 12 are a little small! Let's increase the figure size to `(13, 11)` and the font size to `"x-large"` for both of these graphs in the two cells below:

# %% [markdown]
# **`ShareMen` vs. `Unemployment_rate`**

# %%
plt.figure( figsize=(13,11))

#I had to sort the values for each dataset, otherwise, the line of the graoh would be all over the place...
plt.scatter(earn_df['ShareMen'].sort_values(), earn_df['Unemployment_rate'].sort_values(), color='navy')
plt.title("ShareMen vs. Unemplyment Rate", fontweight='bold', fontsize='x-large')
plt.xlabel("ShareMen", fontweight='bold', fontsize='x-large')
plt.ylabel("Unemployment Rate", fontweight='bold', fontsize='x-large')
plt.show()

# %% [markdown]
# **`ShareWomen` vs. `Unemployment_rate`**

# %%
plt.figure( figsize=(13,11))

#I had to sort the values for each dataset, otherwise, the line of the graoh would be all over the place...
plt.scatter(earn_df['ShareWomen'].sort_values(), earn_df['Unemployment_rate'].sort_values(), color='green')
plt.title("ShareWomen vs. Unemplyment Rate", fontweight='bold', fontsize='x-large')
plt.xlabel("ShareWomen", fontweight='bold', fontsize='x-large')
plt.ylabel("Unemployment Rate", fontweight='bold', fontsize='x-large')
plt.show()

# %% [markdown]
# #####**Step 14:**
#
# Graph the columns `ShareWomen` vs `ShareMen`. Make the points purple, the fontsize `"x-large"`, and the overall figure larger.
#
# This graph should look like a very neat diagonal line... why is that?

# %%
plt.figure( figsize=(16,14))

#I had to sort the values for each dataset, otherwise, the line of the graoh would be all over the place...
plt.scatter(earn_df['ShareWomen'].sort_values(), earn_df['ShareMen'].sort_values(), color='purple')
plt.title("ShareWomen vs. ShareMen", fontweight='bold', fontsize='x-large')
plt.xlabel("ShareWomen", fontweight='bold', fontsize='x-large')
plt.ylabel("ShareMen", fontweight='bold', fontsize='x-large')
plt.show()

#the graph looks almost like a neat diagonal line, because there must be a constant ratio of ShareWomen to ShareMen, which would make their relationship a linear one.

# %% [markdown]
# #####**Step 15:**
#
# Graph the share of men vs. full time jobs as represented by the `Full_time` column. Make the graph and text nice and large. Make the points a color of your choice.

# %%
plt.figure( figsize=(16,14))

#I had to sort the values for each dataset, otherwise, the line of the graoh would be all over the place...
plt.scatter(earn_df['ShareMen'].sort_values(), earn_df['Full_time'].sort_values(), color='maroon')
plt.title("Share of Men vs. Number of Full Time Jobs", fontweight='bold', fontsize='x-large')
plt.xlabel("Share of Men", fontweight='bold', fontsize='x-large')
plt.ylabel("Number of Full Time Jobs", fontweight='bold', fontsize='x-large')
plt.show()

# %% [markdown]
# #####**Step 16:**
#
# Graph the share of women vs. full time jobs as represented by the `Full_time` column. Make the graph and text nice and large. Make the points a color of your choice that is different than in your previous graph.

# %%
plt.figure( figsize=(16,14))

#I had to sort the values for each dataset, otherwise, the line of the graoh would be all over the place...
plt.scatter(earn_df['ShareWomen'].sort_values(), earn_df['Full_time'].sort_values(), color='magenta')
plt.title("Share of Women vs. Number of Full Time Jobs", fontweight='bold', fontsize='x-large')
plt.xlabel("Share of Women", fontweight='bold', fontsize='x-large')
plt.ylabel("Number of Full Time Jobs", fontweight='bold', fontsize='x-large')
plt.show()

# %% [markdown]
# #####**Step 17:**
#
# Now, let's graph the share of men vs. median (salary). Make the graph and text nice and large. Make the points a color of your choice.

# %%
plt.figure(figsize=(12,9))
plt.scatter(earn_df['ShareMen'], earn_df['Median'], color='#85bb65')
plt.title("Share of Men vs. Median Salary", fontsize='large', fontweight='bold')
plt.xlabel("Share of Men", fontsize='large', fontweight='bold')
plt.ylabel("Median Salary", fontsize='large', fontweight='bold')
plt.show()

# %% [markdown]
# #####**Step 18:**
#
# Now, let's graph the share of women vs. median (salary). Make the graph and text nice and large. Make the points a color of your choice that is different than in your previous graph.

# %%
plt.figure(figsize=(12,9))
plt.scatter(earn_df['ShareWomen'], earn_df['Median'], color='#FF6347')
plt.title("Share of Women vs. Median Salary", fontsize='large', fontweight='bold')
plt.xlabel("Share of Women", fontsize='large', fontweight='bold')
plt.ylabel("Median Salary", fontsize='large', fontweight='bold')
plt.show()

# %% [markdown]
# #####**Step 19:**
#
# At this point, we have looked at the relationships between the share of men and women versus unemployment rate, number of full time jobs, and median salary.
#
# Using your graphs, answer the following questions:
# 1. Is there any correlation between the percentage of men/women in a given major and unemployment?
#
# 2. Is there any correlation between the percentage of men/women in a given major and the number of full time jobs?
#
# 3. Is there any correlation between the percentage of men/women in a given major and median salary?
#
# 4. How confident can we be in these results and what other data would we want to collect to understand these results further?

# %%
earn_df.describe()
# Out:
#              Rank   Major_code          Total          Women            Men  \
# count  172.000000   172.000000     172.000000     172.000000     172.000000
# mean    87.377907  3895.953488   39370.081395   22646.674419   16723.406977
# std     49.983181  1679.240095   63483.491009   41057.330740   28122.433474
# min      1.000000  1100.000000     124.000000       0.000000     119.000000
# 25%     44.750000  2403.750000    4549.750000    1778.250000    2177.500000
# 50%     87.500000  3608.500000   15104.000000    8386.500000    5434.000000
# 75%    130.250000  5503.250000   38909.750000   22553.750000   14631.000000
# max    173.000000  6403.000000  393735.000000  307087.000000  173809.000000
#
#        ShareWomen    ShareMen  Sample_size      Employed      Full_time  \
# count  172.000000  172.000000   172.000000     172.00000     172.000000
# mean     0.522223    0.477777   357.941860   31355.80814   26165.767442
# ...

# %% [markdown]
# 1.) The unemployment rates for both men and women in a given major are almost equal.
#
# 2.)There tends to be a slightly lower percentage of women who have full tiem jobs compared to men in a given major.
#
# 3.) There is a small share of women who have a high median salary, while there's a much higher share of men who have a high median salary.
#
# 4.) We can't be completely confident in the results of this data, because we do not where this data came from and who was sampled for this data. Also, 172 rows of data might be ebough to make a correlation between variables, but not enough data to make a confident assertion about it (correlation is not always causation). Collecting data around more universities/colleges would be helpful; Also, I'm not sure on the geographic scope of the data, but maybe collecting data around the world, or around the entire United States would be more helpful to have another insight onto the results of the data.

# %% [markdown]
# #####**YOU ARE DONE!**
#
# If you are feeling like you still want to learn more, here are some options:
#
# 1. Graph any other variables (in different styles) that you think would be cool or check out the optional challenge problems below.
# 2. Check out the [GitHub](https://github.com/sengkchu/dataquest-guided-projects-solutions/tree/master/Guided%20Project_%20Visualizing%20Earnings%20Based%20On%20College%20Majors) that inspired this work. They show that majors with a lower percentage of women tend to earn more.
# 3. Check out [seaborn](https://seaborn.pydata.org). `seaborn` is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics. These graphics will be a bit more aesthetic, and sometimes easier to create.

# %% [markdown]
# ![Screen Shot 2022-07-14 at 4.12.06 PM.png](data:image/png;base64,...)

# %% [markdown]
# ## [Optional] Challenge Problems

# %% [markdown]
# #####**Problem 1:**
#
# Calculate the difference between the *median* and the *mean* number of women in the majors in this dataset. You do not need to know all the nuances of what this difference represents, but take a look at the image below depicting what our data might look like depending on how the median and mean compared. Is this data: **right-skewed**, **left-skewed**, or **symmetric**?

# %% [markdown]
# ![Screen Shot 2022-10-17 at 9.12.27 AM.png](data:image/png;base64,...)

# %%
median = earn_df['Women'].median()
mean = earn_df['Women'].mean()

if median < mean:
  print("The data is right-skewed")
elif mean < median:
  print("The data is left-skewed")
else:
  print("The data is symmetric")
# Out:
# The data is right-skewed

# %% [markdown]
# Here, you can write whether the distribution is:
# Right-skewed
# Left-skewed
# Symmetric
#
#
# The data is Right-Skewed

# %% [markdown]
# #####**Problem 2:**
#
# If you noticed, the column `Full_time_year_percent` is empty! Set this column to be equal to the percentage of people working full time year round out of the total people in our dataset.

# %%
#I wasn't sure if I was supposed to do set the entire column equal to an average percentage
#...or calculate that percentage for each row

percentage_fulltime = (earn_df['Full_time'].sum() / earn_df['Total'].sum() * 100)

index = 0

while(index < 172):
  earn_df['Full_time_year_percent'][index] = (earn_df['Full_time'][index] / earn_df['Total'][index] * 100)
  index = index + 1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
earn_df.shape
# Out:
# (172, 21)

# %% [markdown]
# #####**Problem 3:**
#
# Graph the column `Full_time_year_percent` versus `Unemployment_rate`.

# %%
plt.figure( figsize=(7, 5))
plt.scatter(earn_df['Full_time_year_percent'], earn_df['Unemployment_rate'])
plt.show()

# %% [markdown]
# #####**Problem 4:**
#
# Let's create a bar graph with `Major` on the x-axis and `Total` on the y-axis. Complete the code below to accomplish this.

# %%
plt.figure(figsize=(10, 5))
plt.bar(earn_df['Major'], earn_df['Total'], label='Majors', color='purple')
plt.legend()

# Make sure to add a title and axis labels here!
plt.title("Major vs. Total Number of People")
plt.xlabel("Majors")
plt.ylabel("Total Number of People")

plt.show()

# %% [markdown]
# #####**Problem 5:**
#
# This graph doesn't look very good or informative! That's because we were trying to squeeze way too many categories onto the x-axis.
#
# Complete the code below to make a bar graph with as many majors as possible while still being able to read and make sense of the graph.

# %%
# Complete the code below
num_rows = 170
x = earn_df['Major']
y = earn_df['Total']

plt.bar(x, y, #...)

# %% [markdown]
# #####**Problem 6:**
#
# Look at all the unique major categories. Choose one to create a new data frame with just that category. Fill in the **name** of your data frame and the **category** you would like to look at into the following cell.
#
# Then create a new graph with two variables of your choice from this new data frame!
#
# **Syntax**:
#
# ```python
# new_df = old_df.loc[old_df["Column Name"] == "Value You Are Interest In"]
# ```
#
# This has already been started for you below, but you will need to change it in multiple places to get it working.

# %%
# change the name of new and old df and add what category you would like to create a new DF
new_df = old_df.loc[old_df["Major_category"] == "Yor major category choice"]

new_df
